# %% [markdown]
# <a href="https://colab.research.google.com/github/dudsstar16/ciencia-de-dados-iesb/blob/main/Aula_12_03_Primeiro_Exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(input("Informe o seu Nome: "))
print(input ("Agora insira a sua Idade: "))
# Out:
# Informe o seu Nome: Duda
# Duda
# Agora insira a sua Idade: 22
# 22

# %%
data = int(input("Insira o Ano da sua Data de Nascimento: "))

idade = 2026 - data

print("Sua Idade é em relação a 2026 é: ", idade)
# Out:
# Insira o Ano da sua Data de Nascimento: 2003
# Sua Idade é em relação a 2026 é:  23
